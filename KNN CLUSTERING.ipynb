# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs

# %% [markdown]
# # <font color="green">We can use knn clustering algorithm in both classifiction as well as regression</font>

# %% [markdown]
# # <font color="orange">Making Of Clusters</font>

# %%
X,y=make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
fig=plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
k=5

colors=['green','yellow','blue','cyan','red']
clusters={}

for idx in range(k):
    
    center  = 10*(2*np.random.random((X.shape[1],))-1)
    points  = []
    cluster = {
        
        'center' : center,
        'points' : [],
        'color'  : colors[idx]
        
             }
    clusters[idx]=cluster

# %%
plt.scatter(X[:,0],X[:,1],c=y)

for i in clusters:
    
    center = clusters[i]['center']
    plt.scatter(center[0],center[1],marker = '^',c='red')

plt.show()

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
def distance(v1,v2):
    return np.sqrt(np.mean(v1-v2)**2)

# %%
v1=np.array([1,2])
v2=np.array([3,4])
distance(v1,v2)
# Out:
# 2.0

# %%
def assign_clusters():
    for idx in range(X.shape[0]):
        dist=[]
        
        curr_x=X[idx]
        for i in range(k):
            dis=distance(curr_x,clusters[i]["center"])
            dist.append(dis)
        curr_cluster=np.argmin(dist)
        clusters[curr_cluster]["points"].append(curr_x)

# %%
center
# Out:
# array([-7.9128851 ,  5.29182566])

# %%
X[0]
# Out:
# array([-6.94238952, -6.8807223 ])

# %%
clusters[0]
# Out:
# {'center': array([-2.04430318, -7.60522646]), 'points': [], 'color': 'green'}

# %%
clusters
# Out:
# {0: {'center': array([-2.04430318, -7.60522646]),
#   'points': [],
#   'color': 'green'},
#  1: {'center': array([-2.5883421 , -1.22145046]),
#   'points': [],
#   'color': 'yellow'},
#  2: {'center': array([4.12961655, 9.3402083 ]), 'points': [], 'color': 'blue'},
#  3: {'center': array([ 3.68020889, -4.08214258]),
#   'points': [],
#   'color': 'cyan'},
#  4: {'center': array([-7.9128851 ,  5.29182566]),
#   'points': [],
#   'color': 'red'}}

# %%
assign_clusters()

# %%
def plot_clusters():
    for i in clusters:
        pts=np.array(clusters[i]['points'])
        try:
            plt.scatter(pts[:,0],pts[:,1],c=clusters[i]['color'])
        except:
            pass
        center=clusters[i]['center']
        plt.scatter(center[0], center[1],c = 'black', marker = "^")

# %%
plot_clusters()

# %%
def update_clusters():
    for idx in range(k):
        pts = np.array(clusters[idx]['points'])
        if(pts.shape[0] > 0):
            new_center = pts.mean(axis =0)
            clusters[idx]['center'] = new_center
            clusters[idx]['points'] = []

# %%
assign_clusters()
plot_clusters()
update_clusters()z

# %% [markdown]
# # Kmeans Clusters

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=5)

# %%
X,y=make_blobs(n_samples=500,n_features=2,centers=5,random_state=5)

# %%
km.fit(X,y)
# Out:
# /Users/siddharthnagaych/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
centers=km.cluster_centers_

# %%
plt.scatter(X[:,0],X[:,1])
plt.scatter(centers[:,0],centers[:,1],c='black',marker="^")
plt.show()

# %%
arr_new=np.random.random()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 arr_new=np.random.random(4,5)
#
# File mtrand.pyx:427, in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() takes at most 1 positional argument (2 given)

# %%
arr_new
# Out:
# array([0.7946962 , 0.2560949 , 0.94239181, 0.40756831])
